# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
from pandas.io.formats.excel import ExcelFormatter

url = 'https://portal.sistemafamasul.com.br/cotacoes-online?field_categoria_cot_tid=11&field_data_cot_value_1%5Bvalue%5D%5Bday%5D=&field_data_cot_value_1%5Bvalue%5D%5Bmonth%5D=&field_data_cot_value_1%5Bvalue%5D%5Byear%5D=&undefined=Aplicar&page=0'
html = pd.read_html(url)

response = urlopen(url)
htmls = response.read()
soup = BeautifulSoup

# %%
tabela = html[0]
type(tabela)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(tabela)
print(df)
# Out:
#           Data                 Praça      Valor
# 0   10/06/2022              Dourados  R$ 186.00
# 1   10/06/2022              Maracaju  R$ 184.00
# 2   10/06/2022            Ponta Porã  R$ 182.00
# 3   10/06/2022  São Gabriel do Oeste  R$ 182.50
# 4   10/06/2022           Sidrolândia  R$ 184.00
# ..         ...                   ...        ...
# 95  26/05/2022  São Gabriel do Oeste  R$ 177.40
# 96  25/05/2022            Ponta Porã  R$ 178.00
# 97  25/05/2022  São Gabriel do Oeste  R$ 174.30
# 98  25/05/2022           Sidrolândia  R$ 175.80
# 99  25/05/2022                Sonora  R$ 172.00
#
# [100 rows x 3 columns]

# %%
df.to_csv('tabelinha')

# %%
df.to_excel(r'C:\Users\André\Documents\Alura\Scraping com Python coleta de dados na web\export_dataframe.xlsx', index = False, header=True)

# %% [markdown]
# É TETRAAAAA É TETRAAAAAAAAAAAAA

# %%
htmls = htmls.decode('utf-8')

# %%
soup = BeautifulSoup(htmls, 'html.parser')
type(htmls)
# Out:
# str

# %%
a = soup.find('a', {'title': 'Ir para a última página'})

# %%
a
# Out:
# <a href="/cotacoes-online?field_categoria_cot_tid=11&amp;field_data_cot_value_1%5Bvalue%5D%5Bday%5D=&amp;field_data_cot_value_1%5Bvalue%5D%5Bmonth%5D=&amp;field_data_cot_value_1%5Bvalue%5D%5Byear%5D=&amp;undefined=Aplicar&amp;page=58" title="Ir para a última página">fim »</a>

# %%
a2 = 'https://portal.sistemafamasul.com.br' + a.get('href')

# %%
type(a2)
# Out:
# str

# %%
pages = int(a2[-2:])
print(pages)
# Out:
# 58

# %%
print(a2)
# Out:
# https://portal.sistemafamasul.com.br/cotacoes-online?field_categoria_cot_tid=11&field_data_cot_value_1%5Bvalue%5D%5Bday%5D=&field_data_cot_value_1%5Bvalue%5D%5Bmonth%5D=&field_data_cot_value_1%5Bvalue%5D%5Byear%5D=&undefined=Aplicar&page=58

# %%
tabelas = []

# %%
for i in range(pages):
    tabela = {}
    response = urlopen('https://portal.sistemafamasul.com.br/cotacoes-online?field_categoria_cot_tid=11&field_data_cot_value_1%5Bvalue%5D%5Bday%5D=&field_data_cot_value_1%5Bvalue%5D%5Bmonth%5D=&field_data_cot_value_1%5Bvalue%5D%5Byear%5D=&undefined=Aplicar&page='+str(i + 1))    
    htmls = response.read()
    soup = BeautifulSoup
    

    tabela = html[0]
    df = pd.DataFrame(tabela)
    
    tabelas.append(tabela)

# %%
tabelas
# Out:
# [          Data                 Praça      Valor
#  0   10/06/2022              Dourados  R$ 186.00
#  1   10/06/2022              Maracaju  R$ 184.00
#  2   10/06/2022            Ponta Porã  R$ 182.00
#  3   10/06/2022  São Gabriel do Oeste  R$ 182.50
#  4   10/06/2022           Sidrolândia  R$ 184.00
#  ..         ...                   ...        ...
#  95  26/05/2022  São Gabriel do Oeste  R$ 177.40
#  96  25/05/2022            Ponta Porã  R$ 178.00
#  97  25/05/2022  São Gabriel do Oeste  R$ 174.30
#  98  25/05/2022           Sidrolândia  R$ 175.80
#  99  25/05/2022                Sonora  R$ 172.00
#
#  [100 rows x 3 columns],
#            Data                 Praça      Valor
#  0   10/06/2022              Dourados  R$ 186.00
#  1   10/06/2022              Maracaju  R$ 184.00
#  2   10/06/2022            Ponta Porã  R$ 182.00
#  3   10/06/2022  São Gabriel do Oeste  R$ 182.50
#  4   10/06/2022           Sidrolândia  R$ 184.00
#  ..         ...                   ...        ...
# ...

# %%
for i in range(pages):
    tabela = {}
    response = urlopen('https://portal.sistemafamasul.com.br/cotacoes-online?field_categoria_cot_tid=11&field_data_cot_value_1%5Bvalue%5D%5Bday%5D=&field_data_cot_value_1%5Bvalue%5D%5Bmonth%5D=&field_data_cot_value_1%5Bvalue%5D%5Byear%5D=&undefined=Aplicar&page='+str(i + 1))    
    htmls = response.read()
    soup = BeautifulSoup
    

    tabela = html[0]
    
    tabelas.append(tabela)

# %%
tabelas.to_csv('datasetfinal.csv', sep=';', index = False, encoding = 'utf-8')
tabelas.to_excel(r'C:\Users\André\Documents\Alura\Scraping com Python coleta de dados na web\export_dataframefinal.xlsx', index = False, header=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 tabelas.to_excel(r'C:\Users\André\Documents\Alura\Scraping com Python coleta de dados na web\export_dataframefinal.xlsx', index = False, header=True)
#
# AttributeError: 'list' object has no attribute 'to_excel'

# %%
# Out:
# [          Data                 Praça      Valor
#  0   10/06/2022              Dourados  R$ 186.00
#  1   10/06/2022              Maracaju  R$ 184.00
#  2   10/06/2022            Ponta Porã  R$ 182.00
#  3   10/06/2022  São Gabriel do Oeste  R$ 182.50
#  4   10/06/2022           Sidrolândia  R$ 184.00
#  ..         ...                   ...        ...
#  95  26/05/2022  São Gabriel do Oeste  R$ 177.40
#  96  25/05/2022            Ponta Porã  R$ 178.00
#  97  25/05/2022  São Gabriel do Oeste  R$ 174.30
#  98  25/05/2022           Sidrolândia  R$ 175.80
#  99  25/05/2022                Sonora  R$ 172.00
#
#  [100 rows x 3 columns],
#            Data                 Praça      Valor
#  0   10/06/2022              Dourados  R$ 186.00
#  1   10/06/2022              Maracaju  R$ 184.00
#  2   10/06/2022            Ponta Porã  R$ 182.00
#  3   10/06/2022  São Gabriel do Oeste  R$ 182.50
#  4   10/06/2022           Sidrolândia  R$ 184.00
#  ..         ...                   ...        ...
# ...

# %%
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# como aplicar https://portal.sistemafamasul.com.br/cotacoes-online?field_categoria_cot_tid=11&field_data_cot_value_1%5Bvalue%5D%5Bday%5D=&field_data_cot_value_1%5Bvalue%5D%5Bmonth%5D=&field_data_cot_value_1%5Bvalue%5D%5Byear%5D=&undefined=Aplicar&page=1
#
# page=1 até page=59 ou infinito sendo que page=0 é a primeira
# (testei e funcionou)
